# %%
import numpy as np
import pandas as pd

# %%
data=pd.DataFrame({'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]})

# %%
data.head()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
data.isnull().sum()
# Out:
# First Score     1
# Second Score    1
# Third Score     1
# dtype: int64

# %%
data=data.fillna(data.median())

# %%
data.isnull().sum()
# Out:
# First Score     0
# Second Score    0
# Third Score     0
# dtype: int64

# %%
import pandas as pd 
    
# making data frame from csv file 
data = pd.read_csv("employees.csv") 
    
# creating bool series True for NaN values 
data.isnull().sum()
    
# filtering data 
# displaying data only with Gender = NaN
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data.head(50)
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7         NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
data['Gender'].fillna('no gender',inplace=True)
data['First Name'].fillna('no name',inplace=True)
data['Senior Management'].fillna('no data',inplace=True)
data['Team'].fillna('no data',inplace=True)

# %%
data.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
data.head(50
         )
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1      Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry       Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis       Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby     Female   8/17/1987         4:20 PM   65476   10.012
# 7     no name     Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela     Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances     Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# ...

# %%
import pandas as pd
  
# importing numpy as np
import numpy as np
  
# dictionary of lists
data=pd.DataFrame({'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]})
data.head()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
data.isnull().sum()
# Out:
# First Score     1
# Second Score    1
# Third Score     0
# Fourth Score    3
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# First Score     0
# Second Score    0
# Third Score     0
# Fourth Score    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# First Score     0
# Second Score    0
# Third Score     0
# Fourth Score    0
# dtype: int64

# %%
data.head()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0
